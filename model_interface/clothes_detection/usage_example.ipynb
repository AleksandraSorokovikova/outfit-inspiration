# %%
from yolo_interface import YOLOInterface
from items_dataset import ClothesDataset
from PIL import Image

# %% [markdown]
# Init pathes

# %%
annotations_file = "./annotation.csv"
img_dir = "pinterest/"

# %% [markdown]
# ### Get predictions

# %%
model = YOLOInterface("yolov5s.pt", img_dir)

# %%
results = model.detect(None, annotations_file)

# %% [markdown]
# ### Create dataset

# %%
dataset = ClothesDataset(annotations_file, img_dir)

# %%
image, label = dataset[25]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
image.size
# Out:
# (224, 224)

# %%
label
# Out:
# ('6653f06c445a089b2964d6e7c2c7d25b.jpg', 'Shirts & Tops')
